# %%
data=open("input2.txt",'r')
inpuT=data.read()
l=inpuT.split("\n")
# print(l)
yourscore=0
for i in l:
    if i[0]=='A':
        if i[2]=='X':
            yourpoint=4
            oppoint=4
        elif i[2]=='Y':
            yourpoint=8
            oppoint=2
        else:
            yourpoint=3
            oppoint=9
    elif i[0]=='B':
        if i[2]=='X':
            yourpoint=1
            oppoint=8
        elif i[2]=='Y':
            yourpoint=5
            oppoint=5
        else:
            yourpoint=9
            oppoint=2
    elif i[0]=='C':
        if i[2]=='X':
            yourpoint=7
            oppoint=3
        elif i[2]=='Y':
            yourpoint=2
            oppoint=9
        else:
            yourpoint=6
            oppoint=6
    yourscore+=yourpoint
print(yourscore)

yourscore2=0
for i in l:
    if i[0]=='A':
        if i[2]=='X':
            yourpoint=3
        elif i[2]=='Y':
            yourpoint=4
        else:
            yourpoint=8
    elif i[0]=='B':
        if i[2]=='X':
            yourpoint=1
            oppoint=8
        elif i[2]=='Y':
            yourpoint=5
            oppoint=5
        else:
            yourpoint=9
            oppoint=2
    elif i[0]=='C':
        if i[2]=='X':
            yourpoint=2
            oppoint=3
        elif i[2]=='Y':
            yourpoint=6
            oppoint=9
        else:
            yourpoint=7
            oppoint=6
    yourscore2+=yourpoint
print(yourscore2)



# alternative way using dictionary
scorecard={
    'A X':4, 'A Y':8, 'A Z':3,
    'B X':1, 'B Y':5, 'B Z':9,
    'C X':7, 'C Y':2, 'C Z':6
} #for calculating our scores
points=0
for i in l:
    points+=scorecard[i]

print("The score in first case is",points)


#second part 
# updated score card (x:LOSE),(Y:DRAW),(Z:WIN)
score={
    'A X':3, 'A Y':4, 'A Z':8,
    'B X':1, 'B Y':5, 'B Z':9,
    'C X':2, 'C Y':6, 'C Z':7
}
points2= 0
for j in l:
    points2+=score[j]
    
print("The score in second case is",points2)
# Out:
# 14264
# 12382
# The score in first case is 14264
# The score in second case is 12382
